# %% [markdown]
# <a href="https://colab.research.google.com/github/EdvanilsonBS/Desafio/blob/main/Assistente_virtual_texto_em_voz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts
from gtts import gTTS

text_to_say = "Olá! tudo bem?."

language = "pt"

gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)

gtts_object.save("/content/gtts.wav")

# %%
from IPython.display import Audio

Audio("/content/gtts.wav")

french_text = "Olá! tudo bem?"

french_language = "pt"

french_gtts_object = gTTS(text = french_text,
                          lang = french_language,
                          slow = True)

french_gtts_object.save("/content/french.wav")

Audio("/content/french.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
